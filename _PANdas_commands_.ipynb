# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salaries.csv")

# %% [markdown]
# ##**df|head|tail**##

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %% [markdown]
# ##**columns**##

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %% [markdown]
# ##**Values**##

# %%
# we have values parameter for dataframe and
            # values function for dictionary.

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [markdown]
# ##**Dtypes**##

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# ##**info**##

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# ##**describe**##

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %% [markdown]
# ##**Describe including object column**##

# %%
df.describe(include=object)
# Out:
#         rank discipline   sex
# count     78         78    78
# unique     3          2     2
# top     Prof          B  Male
# freq      46         42    39

# %% [markdown]
# ##**max**##

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.salary.max()
# Out:
# 186960

# %% [markdown]
# ##**min**##

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.salary.min()
# Out:
# 57800

# %% [markdown]
# ##**Mean**##

# %%
df.salary.mean()
# Out:
# 108023.78205128205

# %% [markdown]
# ##**Quantile function**##

# %%
df.salary.quantile(0.25)
# Out:
# 88612.5

# %%
df.salary.quantile(0.50)
# Out:
# 104671.0

# %%
df.salary.quantile(0.75)
# Out:
# 126774.75

# %%
df.salary.quantile(0.80)
# Out:
# 130323.0

# %% [markdown]
# ##**standard deviation**##

# %%
df.salary.std()
# Out:
# 28293.66102226417

# %% [markdown]
# # There are two types of data structure in pandas...

# %% [markdown]
# #**Series**#

# %%
series=df.salary
series
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# ##**Value counts**##

# %%
df.sex.value_counts()
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %% [markdown]
# ##**Groupby**##

# %%
df.groupby(["sex"]).salary.mean()
# Out:
# sex
# Female    101002.410256
# Male      115045.153846
# Name: salary, dtype: float64

# %%
df.groupby(["rank"]).salary.max()
# Out:
# rank
# AssocProf    119800
# AsstProf      97032
# Prof         186960
# Name: salary, dtype: int64

# %%
df.groupby(["rank","discipline"]).salary.mean()
# Out:
# rank       discipline
# AssocProf  A              73959.800000
#            B             102927.750000
# AsstProf   A              74450.000000
#            B              86390.272727
# Prof       A             111935.695652
#            B             135313.913043
# Name: salary, dtype: float64

# %% [markdown]
# ##**Shape**##

# %%
df.salary.shape
# Out:
# (78,)

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %% [markdown]
# ##**Cross Table**##

# %%
pd.crosstab(df["sex"],df["rank"])
# Out:
# rank    AssocProf  AsstProf  Prof
# sex
# Female         10        11    18
# Male            3         8    28

# %%
pd.crosstab(df["rank"],df["discipline"])
# Out:
# discipline   A   B
# rank
# AssocProf    5   8
# AsstProf     8  11
# Prof        23  23

# %% [markdown]
# #Extraction of data from Data frame#

# %% [markdown]
# ###top 50 records###

# %%
top50df=df.head(50)
top50df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %% [markdown]
# ###extract a particular column###

# %%
df["salary"]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# ##one condition##
# ###Salary more than>120000

# %%
df[df.salary>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %% [markdown]
# ##Two conditions##
# ###Gender of employee should be "male"###
# ###salary should be more than 150000

# %%
conditions2=df[(df["sex"]=="Male")&(df["salary"]>150000)]
conditions2
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %% [markdown]
# #Index location(iloc)#

# %% [markdown]
# ####extract particular index record

# %%
df.iloc[1]
# Out:
# rank           Prof
# discipline        A
# phd              12
# service           6
# sex            Male
# salary        93000
# Name: 1, dtype: object

# %% [markdown]
# ####To extract random records

# %%
df.iloc[[10,12,14,16,18], ]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 12  AsstProf          B    1        0  Male   88000
# 14      Prof          B   25       19  Male  153750
# 16  AsstProf          B    8        3  Male   75044
# 18      Prof          A   19        7  Male  107300

# %% [markdown]
# ###positive indexing###

# %%
df.iloc[0:10:2]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 2       Prof          A   23       20  Male  110515
# 4       Prof          B   20       18  Male  104800
# 6  AssocProf          A   20       17  Male   81285
# 8       Prof          A   29       19  Male   94350

# %% [markdown]
# ####negative indexing####

# %%
df.iloc[10:0:-2]
# Out:
#          rank discipline  phd  service   sex  salary
# 10       Prof          B   39       33  Male  128250
# 8        Prof          A   29       19  Male   94350
# 6   AssocProf          A   20       17  Male   81285
# 4        Prof          B   20       18  Male  104800
# 2        Prof          A   23       20  Male  110515

# %% [markdown]
# ####TO extract columns and rows ( : , : )

# %%
df.iloc[1:3,0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23

# %% [markdown]
# ####Extracting all columns and range of records only

# %%
df.iloc[1:4, ]
# Out:
#    rank discipline  phd  service   sex  salary
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %% [markdown]
# ####Extracting all rows and some range of column only

# %%
df.iloc[:,1:3]
# Out:
#    discipline  phd
# 0           B   56
# 1           A   12
# 2           A   23
# 3           A   40
# 4           B   20
# ..        ...  ...
# 73          B   18
# 74          B   19
# 75          B   17
# 76          A   28
# 77          A   23
#
# [78 rows x 2 columns]
